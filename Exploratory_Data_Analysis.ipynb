# %% [markdown]
# # Exploratory Analysis

# %%
# Load and inspect dataset
df = read.csv("data/mental_health_social_media_dataset.csv")
head(df, 10)
# Out:
#    person_name      age date      gender platform  daily_screen_time_min
# 1  Reyansh Ghosh    35  1/1/2024  Male   Instagram 320
# 2  Neha Patel       24  1/12/2024 Female Instagram 453
# 3  Ananya Naidu     26  1/6/2024  Male   Snapchat  357
# 4  Neha Das         66  1/17/2024 Female Snapchat  190
# 5  Reyansh Banerjee 31  1/28/2024 Male   Snapchat  383
# 6  Myra Kale        25  2/8/2024  Female Snapchat  516
# 7  Ananya Kulkarni  29  2/19/2024 Other  Snapchat  328
# 8  Meera Das        28  1/11/2024 Female Facebook  394
# 9  Vihaan Naidu     31  1/22/2024 Male   Facebook  326
# 10 Meera Patil      26  2/2/2024  Female Facebook  339
#    social_media_time_min negative_interactions_count
# 1  160                   1
# 2  226                   1
# 3  196                   1
# 4  105                   0
# 5  211                   1
# 6  284                   1
# 7  180                   1
# 8  138                   1
# 9  114                   0
# 10 119                   0
# ...
